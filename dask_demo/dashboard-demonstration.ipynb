# %% [markdown]
# ### Create local Client

# %%
from dask.distributed import Client
client = Client()
client
# Out:
# 2022-04-21 18:05:17,235 - distributed.diskutils - INFO - Found stale lock file and directory '/home/schlich/dask-demo/dask_demo/dask-worker-space/worker-bu5bt_st', purging
# 2022-04-21 18:05:17,237 - distributed.diskutils - INFO - Found stale lock file and directory '/home/schlich/dask-demo/dask_demo/dask-worker-space/worker-_8j9npl1', purging
# 2022-04-21 18:05:17,238 - distributed.diskutils - INFO - Found stale lock file and directory '/home/schlich/dask-demo/dask_demo/dask-worker-space/worker-lnotmyve', purging
# 2022-04-21 18:05:17,239 - distributed.diskutils - INFO - Found stale lock file and directory '/home/schlich/dask-demo/dask_demo/dask-worker-space/worker-hfrtsmo0', purging
# <Client: 'tcp://127.0.0.1:35145' processes=4 threads=8, memory=12.27 GiB>

# %% [markdown]
# ### Small computation to show off diagnostic pages

# %%
import dask.array as da
# x = da.random.random((10000, 10000, 10))
# y = da.random.random((10000, 10000, 10))
x = da.random.random((10000, 10000, 10), chunks=(100, 100, 5))
y = da.random.random((10000, 10000, 10), chunks=(100, 100, 5))
z = (da.arcsin(x) + da.arccos(y)).sum(axis=(1, 2))
z.compute()

# %%
del z

# %% [markdown]
# ### Computations to look at overhead and chunking

# %%
# %%time
x = da.random.random(10_000_000, chunks=(10_000_000,))
x.sum().compute()

# %% [markdown]
# ### Read Parquet to show off Profiler

# %%
import dask.dataframe as dd
df = dd.read_parquet('nyc-2016.parquet/')
df.head()

# %%
# %time df.passenger_count.sum().compute()
